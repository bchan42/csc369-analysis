# %% [markdown]
# # OSM Data Cleaning

# %%
# imports 
import pandas as pd

# %% [markdown]
# ## Perform data cleaning & start exploration

# %%
slofood_parquet = pd.read_parquet('slo_food.parquet')
slodining_parquet = pd.read_parquet('slo_dining.parquet')
davisfood_parquet = pd.read_parquet('davis_food.parquet')
davisdining_parquet = pd.read_parquet('davis_dining.parquet')
athensfood_parquet = pd.read_parquet('athens_food.parquet')
athensdining_parquet = pd.read_parquet('athens_dining.parquet')

slofood_parquet.head()
# Out:
#           id                 timestamp        lat         lon    amenity  \
# 0  573859956 2024-03-19 13:03:23+00:00  35.249339 -120.642032  fast_food
# 1  573864452 2024-06-20 01:42:44+00:00  35.250500 -120.642315       cafe
# 2  574262633 2024-05-10 23:40:16+00:00  35.249171 -120.643033       cafe
# 3  574262980 2024-05-10 21:22:16+00:00  35.250088 -120.643591  fast_food
# 4  581314991 2013-05-08 21:31:51+00:00  35.272740 -120.668584       None
#
#                 brand      cuisine                name    shop
# 0  Jersey Mike's Subs     sandwich  Jersey Mike's Subs    None
# 1           Starbucks  coffee_shop           Starbucks    None
# 2           Starbucks  coffee_shop           Starbucks    None
# 3           Taco Bell      tex-mex           Taco Bell    None
# 4                None         None       Farb's Bakery  bakery

# %%
# check data type
print(slofood_parquet.dtypes)
print(davisfood_parquet.dtypes)
print(athensfood_parquet.dtypes)
# Out:
# id                        object
# timestamp    datetime64[ns, UTC]
# lat                      float64
# lon                      float64
# amenity                   object
# brand                     object
# cuisine                   object
# name                      object
# shop                      object
# dtype: object
# id                        object
# timestamp    datetime64[ns, UTC]
# lat                      float64
# lon                      float64
# amenity                   object
# brand                     object
# cuisine                   object
# name                      object
# shop                      object
# dtype: object
# id                        object
# timestamp    datetime64[ns, UTC]
# lat                      float64
# lon                      float64
# amenity                   object
# name                      object
# shop                      object
# cuisine                   object
# brand                     object
# dtype: object

# %% [markdown]
# ^^ This should be fine. Everything besides timestamp, latitude, and longitude can be a string (object).

# %%
# check nulls (can keep in dataset)

print(slofood_parquet.isna().sum())
print('\n', davisfood_parquet.isna().sum())
print('\n', athensfood_parquet.isna().sum())
# Out:
# id             0
# timestamp      0
# lat            0
# lon            0
# amenity       30
# brand        259
# cuisine      170
# name          84
# shop         269
# dtype: int64
#
#  id             0
# timestamp      0
# lat            0
# lon            0
# amenity       11
# brand        123
# cuisine       58
# name           9
# shop         163
# dtype: int64
#
#  id             0
# timestamp      0
# lat            0
# lon            0
# amenity       47
# name          41
# shop         288
# cuisine      185
# brand        283
# dtype: int64

# %% [markdown]
# ^^ Nulls in `amenity`, `brand`, `cuisine`, and `shop` make sense since a food place may not be inside on of its categories. For example, a local restuarant will not be in a big brand. I would not need to remove these missing values since I know they have tag elsewhere.
#
# * But I want to check if there are spots with no description, and
# * I want to look at why `name` can be null.

# %%
# check if there are spots where all of the rows are null

print(len(slofood_parquet[slofood_parquet[['amenity', 'brand', 'cuisine', 'shop']].isnull().all(axis=1)]))
print(len(davisfood_parquet[davisfood_parquet[['amenity', 'brand', 'cuisine', 'shop']].isnull().all(axis=1)]))
print(len(athensfood_parquet[athensfood_parquet[['amenity', 'brand', 'cuisine', 'shop']].isnull().all(axis=1)]))
# Out:
# 0
# 0
# 0

# %%
# check rows where 'name' is NaN
slofood_parquet[slofood_parquet['name'].isna()]
# Out:
#               id                 timestamp        lat         lon  \
# 19    1542001431 2022-10-30 20:09:34+00:00  35.300251 -120.662176
# 31    2119523722 2018-07-30 03:17:46+00:00  35.390997 -120.609380
# 37    2213049089 2019-03-08 07:07:51+00:00  35.289045 -120.664937
# 44    2262092650 2013-04-10 21:57:32+00:00  35.293103 -120.674052
# 76    2456191971 2024-03-10 17:11:34+00:00  35.280040 -120.661687
# ..           ...                       ...        ...         ...
# 286  11916083274 2024-05-18 14:52:14+00:00  35.280724 -120.659657
# 287  11916083275 2024-05-18 14:52:14+00:00  35.280766 -120.659281
# 288  11930836866 2024-05-24 14:47:50+00:00  35.267077 -120.674566
# 289  11930863369 2024-05-24 14:47:50+00:00  35.263561 -120.677559
# 290  11930863380 2024-05-24 14:47:50+00:00  35.290311 -120.664879
#
#              amenity brand cuisine  name  shop
# 19   vending_machine  None    None  None  None
# 31        restaurant  None    None  None  None
# 37         fast_food  None    None  None  None
# 44               bbq  None    None  None  None
# 76         fast_food  None   pizza  None  None
# ..               ...   ...     ...   ...   ...
# 286  vending_machine  None    None  None  None
# 287  vending_machine  None    None  None  None
# 288  vending_machine  None    None  None  None
# 289  vending_machine  None    None  None  None
# 290              bbq  None    None  None  None
#
# [84 rows x 9 columns]

# %% [markdown]
# ^^ Name is null for local restaurants (that don't have much information on them), and also I included amenties where it is just a BBQ Picnic Spot at parks and vending machines, where both clearly would not have a name.

# %%
# number of places for each town

print("Number food places in SLO:", len(slofood_parquet))
print("Number food places in Davis:", len(davisfood_parquet))
print("Number food places in Athens:", len(athensfood_parquet))
# Out:
# Number food places in SLO: 301
# Number food places in Davis: 174
# Number food places in Athens: 337

# %% [markdown]
# ^^ Originally, I was looking at just SLO and Davis, however, Davis does not have many food places, so it might not be the best place to compare with SLO. I decided to add Athens, GA to the list, and it seems a little more comparable to SLO, both have over 300 food spots.

# %% [markdown]
# I also want to look at how the values for `amenity`, `brand`, `cuisine`, `name`, and `shop` look.

# %%
for col in ['amenity', 'brand', 'cuisine', 'name', 'shop']:
    if col in slofood_parquet.columns:
        print(f"Unique values in {col} (SLO):\n", slofood_parquet[col].dropna().unique())
        print("------")
    
    if col in davisfood_parquet.columns:
        print(f"Unique values in {col} (Davis):\n", davisfood_parquet[col].dropna().unique())
        print("------")

    if col in athensfood_parquet.columns:
        print(f"Unique values in {col} (Athens):\n", athensfood_parquet[col].dropna().unique())
        print("------")
# Out:
# Unique values in amenity (SLO):
#  ['fast_food' 'cafe' 'restaurant' 'bar' 'vending_machine' 'pub' 'bbq'
#  'ice_cream' 'biergarten']
# ------
# Unique values in amenity (Davis):
#  ['fast_food' 'vending_machine' 'cafe' 'pub' 'restaurant' 'ice_cream' 'bbq'
#  'bar']
# ------
# Unique values in amenity (Athens):
#  ['restaurant' 'pub' 'bar' 'pharmacy' 'cafe' 'fast_food' 'ice_cream' 'bbq'
#  'vending_machine']
# ------
# Unique values in brand (SLO):
#  ["Jersey Mike's Subs" 'Starbucks' 'Taco Bell' '7-Eleven' "Domino's"
#  'Subway' 'Panda Express' 'Five Guys' 'Redbox' 'El Pollo Loco'
#  'The Habit Burger Grill' 'Rocky Mountain Chocolate Factory' 'Papyrus'
#  'Jamba' "See's Candies" 'Popeyes' 'Which Wich?' 'Round Table Pizza'
#  'Blaze Pizza' 'Yogurtland' 'Costco' 'Insomnia Cookies'
#  'Einstein Bros. Bagels']
# ------
# Unique values in brand (Davis):
#  ['Del Taco' 'KFC' "Peet's Coffee" 'Jack in the Box' 'Taco Bell' 'Chipotle'
#  'Starbucks' "Noah's Bagels" 'Jamba' 'The Habit Burger Grill'
#  'Panera Bread' 'Burger King' "Domino's" "Papa Murphy's" 'Quickly'
#  'Dutch Bros. Coffee' 'Subway' 'Round Table Pizza' 'Baskin-Robbins'
#  'Sharetea' 'Gong Cha' 'Wingstop' 'Blaze Pizza' 'Philz Coffee'
#  'Little Caesars' "Mountain Mike's" 'Panda Express' "Denny's"
#  "Ike's Love and Sandwiches" "Raising Cane's"]
# ------
# Unique values in brand (Athens):
#  ['Smoothie King' 'Mellow Mushroom' 'Five Guys' 'Starbucks' "Ben & Jerry's"
#  'Crumbl Cookies' 'Einstein Bros. Bagels' 'American Deli' 'Chick-fil-A'
#  "Taziki's Mediterranean Cafe" 'Pita Pit' 'Insomnia Cookies'
#  'Waffle House' 'Shell' 'Little Caesars' 'Chipotle' "Beef O'Brady's"
#  'Mochinut' "Jimmy John's" "Dunkin'" 'Planet Smoothie'
#  'Chicken Salad Chick' 'Pizza Factory' "Marco's Pizza" 'Cicis' 'Chevron'
#  'Subway' "Domino's" 'Chuck E. Cheese' "Papa John's" 'TA' 'Pizza Hut'
#  'Panda Express' 'Clean Eatz' 'Nothing Bundt Cakes' "McDonald's"
#  'Panera Bread']
# ------
# Unique values in cuisine (SLO):
#  ['sandwich' 'coffee_shop' 'tex-mex' 'sushi' 'cajun' 'thai' 'bagel'
#  'mediterranean' 'pizza;wine;beer' 'pizza' 'irish' 'mexican' 'ramen'
#  'chinese' 'burger' 'breakfast' 'japanese' 'italian' 'barbecue' 'asian'
#  'juice' 'indian' 'crepe' 'american' 'french' 'international' 'german'
#  'burger;diner' 'chicken' 'turkish' 'frozen_yogurt' 'poke' 'bakery'
#  'steak_house' 'hot_dog;pizza;sandwich' 'mexican;burrito' 'bubble_tea'
#  'noodle;japanese;ramen' 'sushi;poke' 'american;mexican;ice_cream'
#  'noodle' 'street_food;burger;mexican;american' 'chicken;sandwich'
#  'peruvian' 'coffee_shop;bistro' 'cookies' 'fish']
# ------
# Unique values in cuisine (Davis):
#  ['mexican' 'chicken' 'coffee_shop' 'pizza' 'burger' 'tex-mex' 'ice_cream'
#  'breakfast' 'burger;fries;drinks' 'japanese;sushi;seafood' 'regional'
#  'pizza;salad;wings' 'thai' 'burger;american' 'bagel' 'juice' 'hot_dog'
#  'chinese;dumpling' 'sushi' 'sandwich;bakery'
#  'american;burger;sandwich;chicken;breakfast' 'cake' 'asian' 'bubble_tea'
#  'japanese;sushi' 'chinese' 'organic;local' 'sandwich' 'indian' 'japanese'
#  'tea;coffee' 'american' 'italian' 'wings' 'noodle;asian'
#  'sushi;japanese;buffet' 'bagel;breakfast;tea' 'chinese;italian'
#  'tex-mex;mexican' 'sandwich;soup' 'bubble_tea;cafe' 'french'
#  'mediterranean' 'vietnamese' 'american;burger;chicken' 'american;mexican'
#  'greek']
# ------
# Unique values in cuisine (Athens):
#  ['coffee_shop' 'burger' 'regional' 'american' 'japanese' 'mediterranean'
#  'juice' 'seafood' 'mexican' 'chinese;japanese;thai;asian;fusion' 'bagel'
#  'pizza' 'ice_cream' 'ethiopian;eritrean' 'burger;american'
#  'japanese;korean' 'chicken' 'bubble_tea' 'dessert' 'pita' 'thai' 'wings'
#  'chinese' 'pizza;wings' 'japanese;hawaiian' 'italian;pizza' 'italian'
#  'deli' 'vietnamese' 'asian' 'breakfast' 'indian' 'donut;bubble_tea'
#  'sandwich' 'donut;coffee_shop' 'smoothie' 'seafood;vietnamese' 'korean'
#  'pizza;buffet' 'wings;burger' 'sushi' 'greek' 'bubble_tea;asian'
#  'southern' 'wings;breakfast' 'pizza;sandwich'
#  'sandwich;burger;pizza;salad' 'sandwich;bakery']
# ------
# Unique values in name (SLO):
#  ["Jersey Mike's Subs" 'Starbucks' 'Taco Bell' "Farb's Bakery"
#  'Slo Asian Market' 'SLO Provisions' 'Black Sheep Bar & Grill'
#  "Woodstock's Pizza" 'Yanagi Sushi' 'Bon Temps Creole Cafe' 'My Thai'
#  "Gus's Grocery" 'Village Market' '7-Eleven' 'House of Bagels'
#  'Jaffa Cafe' 'Health Snacks' 'Mustang Station'
#  'Blackhorse Espresso and Bakery' "Domino's" "Charlie's Place"
#  "SLO Beverage 'n More" 'Subway' 'Laurel Lane Liquors' "Pappy McGregor's"
#  'Chronic Tacos' "Nucci's" "Sally Loo's Wholesome Cafe"
#  'Crossroads Liquor & Deli' "Sandy's Deli & Liquor" 'Raku Ramen'
#  "Capriottti's Sandwich Shop" 'Panda Express' 'SLO Donut Company'
#  'Five Guys' "Nucci's Pizza" 'Redbox' 'El Pollo Loco'
#  "Pancho's Mexican Food" 'Eureka! Burger' "Louisa's Place"
#  "Linnaea's Cafe" "Eddie's Grill" 'Thai Boat' "Kona's Deli"
#  'Kumi-Ko Japanese' 'The Habit Burger Grill' 'Nautical Bean' 'La Locanda'
#  'Rocket Fizz' 'Central Coast Wines' 'New Earth Superfoods' "Jan's Place"
#  'CJ’s BBQ' 'Thai Palace' 'Aisuru Sushi' "Bowl'd" "Bull's Tavern"
#  "Pluto's" 'Bings Bao Buns' 'UBATUBA, Acai bowls' 'Shadow Canyon Cellars'
#  'Rocky Mountain Chocolate Factory' "Giuseppe's Cucina Rustica"
#  "Doc Bernstein's Ice Cream Lab" "McConnell's Fine Ice Creams"
#  'Brown Butter Cookie Company' 'Urbane Cafe'
#  "Pancho Villa's Mexican Restaurant" 'Creeky Tiki' 'Jamba' 'Taj Palace'
#  "See's Candies" 'Le Ciel Crepe Cafe' 'Flour House' 'Old San Luis BBQ Co'
#  'Burger Village' 'Outspoken Cafe' 'Tacos De Acapulco' 'The Bobastop'
#  'Sushi Kokku' 'Taqueria Santa Cruz Express'
#  'Mama Ganache Artisan Chocolates' 'Goshi Japanese Restaurant'
#  'Laguna Bar and Grill' 'Ribline' 'Et Voilà' 'Stephen Ross Wine Cellars'
#  'Budget Cafe' 'Red Radish' 'Tacos de Aculpuco' 'Sweetie Cup Tea House'
#  "Beda's Biergarten" 'Cool Cat Cafe' 'Freshh Donuts' 'Taco Roco'
#  "Tahoe Joe's" 'Popeyes' 'Apple Farm' 'Koberl at Blue' 'Which Wich?'
#  'Nautical Bean Espresso Cafe' 'Luis Wine Bar' 'Coastal Peaks Roasters'
#  "Doc's Cellar" 'Sidecar' 'Scout Coffee Co.' 'Oki Momo'
#  'Round Table Pizza' "Fatte's Pizza" 'The Neighborhood' 'Blaze Pizza'
#  'San Luis Fish BBQ' 'Central Coast Brewing' 'Hoagies'
#  "McCarthy's Irish Pub" 'Kreuzberg'
#  'The Libertine Brewing Company and Coffee Bar' "Mother's Tavern"
#  'Buffalo Pub and Grill' 'LOKUM' 'Batch' 'Scout Coffee Company'
#  'Tacos Y Birria Sinalos' 'Novo Restaurant & Lounge'
#  'Metro Brewing Company' 'Buona Tavola' 'Mint and Craft'
#  'Mee Heng Low Noodle House' 'SLO Sweets' 'Yogurtland' 'Firestone Grill'
#  'Blackhorse Espresso & Bakery - Uptown' 'Granada Hotel & Bistro'
#  'Mongo Madness' 'The Library' 'Seeds' 'SLO Cafe & Market Place'
#  'Cerro Caliente Cellars' 'SLO Maid Ice Cream' 'Aloha Cafe' 'Front Porch'
#  'PokiRito' "Tonita's" 'Secret Garden' 'Le Petit Paris'
#  'Bang the Drum Brewery' 'House of Bread' 'Ox & Anchor' 'Piadina'
#  'S.Low Bar' 'Cornercopia Fresh Market' 'Costco Food Court'
#  'La Esquina Taqueria' 'Taqueria Santa Cruz Express 2' 'Milk Tea Society'
#  'Milk In It' 'Insomnia Cookies' 'Poke Chef' "Ziggy's"
#  'Market Grand Avenue' 'Balance Cafe' 'Hearth' 'Brunch' 'Noodles'
#  'Sweet Bar' 'Streats' 'Mingle + Nosh' 'Shake Smart' "Julian's"
#  'Einstein Bros. Bagels' 'La Esquina Distillery' 'The Mark Bar & Grill'
#  'Snofari Frozen Yogurt' "Mr. Pickle's Sandwich Shop"
#  'Efren’s Mexican Restaurant' 'Alex Madonna Gold Rush Steakhouse'
#  'Copper Cafe' 'Silver Bar Cocktail Lounge' "Jay Bird's" 'Bread Bike'
#  'Corazon Cafe SLO' '15 Degrees C' "My Friend Mike's" 'Coya Peruvian'
#  'Nautical Bean - Bunker' 'Cowboy Cookie and Ice Cream' 'Ancient Owl'
#  'Kaffein Coffee Company' 'Cal Poly Meats' 'Pizza Republic'
#  'Negranti Creamery' 'Arigato Sushi' 'Deltina Coffee' 'Tiki Hut'
#  'Lure Fish House']
# ------
# Unique values in name (Davis):
#  ['Del Taco' 'KFC' 'Cargo Coffee' 'Sodexho Coffee' 'Bio Brew'
#  "Peet's Coffee" 'Gunrock Pub' "Steve's Pizza" 'Jack in the Box'
#  'Taco Bell' 'Chipotle' 'Cultivé Frozen Yogurt' 'Crepeville'
#  'Burgers and Brew' 'Yolo Berry' 'Silver Dragon' 'Make Fish' 'Bistro 33'
#  "Woodstock's Pizza" 'Kathmandu Kitchen' 'Village Bakery'
#  'Davis Noodle City' 'Davis Creamery' "Sophia's Thai Kitchen"
#  'Village Pizza & Grill' 'Redrum Burger' 'Starbucks'
#  'Taqueria Guadalajara' 'Dos Coyotes' "Noah's Bagels" 'Jamba'
#  'Lamppost Pizza' 'Shanghai Town' "Chuy's Taqueria"
#  'Symposium Restaurant & Pizza House' 'Taste of Thai' 'The Hotdogger'
#  'The Dumpling House' 'Snack Shack' 'Sudwerk Brewing Co. The Dock'
#  'The Habit Burger Grill' "Mikuni's" 'Panera Bread' "Shah's Halal Food"
#  'CoHo South Café' 'Cuarto Dining Commons' 'Segundo Dining Commons'
#  'Tercero Dining Commons' 'Burger King' "Domino's" 'KetMoRee' 'Konditorei'
#  'Let Them Eat Cake' 'Ding How' "Papa Murphy's" 'Quickly' 'I Love Sushi'
#  'Sage Street Cafe' 'Sage Street Restaurant' 'Sage Street Market'
#  'Wok of Flame' 'Fluffy Donuts' 'The Old Teahouse' 'The Graduate'
#  'Coffee House' "Natural Food Works and Farmer's Kitchen Cafe"
#  'Dutch Bros. Coffee' 'El Toro Bravo' 'Subway' 'Round Table Pizza'
#  '3rd and U Cafe' 'Ali Baba Cafe' 'Pho King 4 Restaurant' 'Oshio Cafe'
#  "Raja's Tandoor" 'Baskin-Robbins' 'Manna Korean BBQ'
#  'Taqueria El Burrito' 'Yeti Restaurant' "Zia's Delicatessen"
#  'Taqueria Davis' 'Thai Canteen' "Pluto's" 'Yakitori Yuchan'
#  'The Davis Beer Shoppe' 'Common Grounds Coffee' 'Tea List' 'Sharetea'
#  'Barista Brew Cafe' 'Cafe Bernardo' 'Cloud Forest Cafe' "Bull 'N Mouth"
#  'Burger Patch' 'Temple Coffee' 'Bar Bernardo' "Jack's Urban Eats"
#  'University of Beer' 'vini' 'Gong Cha' "Paesano's" 'Wingstop'
#  'Red 88 Noodle Bar' 'Fuji Sushi Boat & Buffet' 'Preethi Indian Cuisine'
#  'The Posh Bagel' 'Blaze Pizza' 'Four Seasons Gourmet Chinese'
#  'Dos Coyotes Border Cafe' "Mr Pickle's Sandwich Shop" 'Teabo Café'
#  'La Cocina Mexicana Restaurante' "Davis's Piñata Mexican Grill"
#  'Fushion Fresh Cafe' 'Philz Coffee' 'Dunloe Brewing' 'Huku Bistro'
#  'Little Caesars' 'Carniceria Lupita' 'Asian Garden' 'Burma Eat'
#  "Mountain Mike's" 'Panda Express' 'Crepe Bistro' 'Spokes Grill'
#  'Silo Market' "Denny's" 'Lazi Cow' 'Latitude Restaurant' 'Wundebar'
#  'Xi Square' 'Hunan Style' "Ike's Love and Sandwiches" 'Pachamama Coffee'
#  "Froggy's" "Raising Cane's" 'Sit Lo Saigon' "Kiki's Chicken Place"
#  'Insomnia cookies' 'Myu Myu' 'El patio' 'Nick the Greek']
# ------
# Unique values in name (Athens):
#  ['The National' "Jittery Joe's Coffee" 'Baddies' 'Birdies'
#  'Big City Bread Cafe' 'Pulaski Heights BBQ' 'Trappeze Pub'
#  'Manhattan Cafe' 'Little Kings Shuffle Club' 'The Roadhouse' 'The Globe'
#  'Bar South' 'Woodford' 'Cutters Pub' "Pauley's Crepe Bar" 'Rye Bar'
#  "General Beauregard's" 'City Bar' "Walker's Coffee and Pub"
#  'Blue Sky Bar' "Magnolia's" 'Bourbon Street' 'Buddha Bar'
#  '1785 Bar & Grill' "Flanagan's & The Half Moon Pub" 'Allgood Lounge'
#  'On The Rocks' "Boar's Head Lounge" 'South Kitchen + Bar'
#  'The Pine Bar & The Root Basement' 'Sakura Hibachi & Sushi Bar'
#  "Hodgson's Pharmacy & Gift Shop" 'Mediterranean Grill'
#  'Independent Baking Company' 'Smoothie King' 'Dawg Gone Good BBQ'
#  'Square One Fish Co.' "Em's Kitchen" 'La Cabana de Don Juan' 'Athens Wok'
#  'Athens Bagel Company' 'Mellow Mushroom' 'The Grill' 'Five Guys'
#  'Ten Pins Tavern' 'The World Famous' 'Starbucks' 'Sabor Latino'
#  "Ben & Jerry's" 'Hi-Lo Lounge' 'The Old Pal' 'Crumbl Cookies'
#  'JR Crickets' 'Mannaweenta' 'Lighthouse Seafood' 'Vanish Night Club'
#  'Blind Pig Tavern' 'Einstein Bros. Bagels' 'Taqueria La Parrilla'
#  'Choo Choo' 'American Deli' "Mama Sid's Pizza" 'Ideal Bagel Co.'
#  'Chick-fil-A' "Jittery Joe's" 'Cravings' 'LRG Provisions' 'Clocked'
#  "Taziki's Mediterranean Cafe" 'Ding Tea' 'The Office' '1000 Faces Coffee'
#  'Buvez!' 'Pelican’s Snoballs' 'Pita Pit' 'Taqueria Tsunami' 'Cozy Bar'
#  'Wonderbar' 'Spirits on Washington' 'SandBar' 'The Silver Dollar Bar'
#  'Insomnia Cookies' 'Bad Moon' 'Moonshine Bar' 'Eddie’s Calzones & Drafts'
#  'Amici' 'Barberitos' "Sister Louisa's Church" 'Tropical Bar' 'Shokitini'
#  'Creature Comforts' 'Frogger' 'Hendershot’s' 'Pretty Boy'
#  'Seabear Oyster Bar' 'Ponko Chicken' 'Wingster' 'Waffle House'
#  'Golden Pantry Market' 'Fast Trac' 'Journey Juice' "Sam's" 'Agua Linda'
#  'Normal Bar' 'Oglethorpe Bar' 'Tall Boy Beverage Company' 'Fooks Foods'
#  'China 1' 'Bulldawg Pizza & Wings' 'Shell' 'Golden Dragon'
#  'Little Caesars' 'Ahi Hibachi and Poke' "Iguana's Mexican Grill"
#  'J. Christopher’s' 'Heirloom Cafe' 'Vickars Nutritionist' 'Chipotle'
#  'Lindsey’s Culinary Market' 'Farm Burger' 'Lumberjaxe' 'Tapped Athens'
#  'Last Resort Grill' 'Flicker Theatre & Bar'
#  'Empourium Rooftop and Lounge' 'Canyons-Convenience Store'
#  "Clarke's Collective" 'Bear Hug Honey' 'The Rook & Pawn'
#  'Alumni Cookie Dough' 'DP Dough' 'Thai Spoon' 'Little Italy'
#  "DePalma's Italian Cafe" 'The Double Barrel' 'Porterhouse Grill'
#  'Up Dawg' 'JINYA Ramen Bar' 'Osteria Athena' 'Bruxie' 'Munch Hut'
#  'Mother Phở' 'Taichi Bubble Tea' 'Four Fat Cows' 'Choco Pronto'
#  'Slutty Vegan' 'Newk’s Eatery' 'Camino Real Taqueria'
#  'Village Wine & Spirits' 'Inoko Hibachi Express Eastside'
#  "Beef O'Brady's" 'The Taco Stand' 'Locos Grill & Pub'
#  'Depalmas Italian Cafe' 'New Red Bowl Asian Bistro' 'Groove Burgers'
#  'The Flying Biscuit Cafe' 'Just Phở ...and More' 'Booze R Uals'
#  'Surcheros' 'The Juicy Crab' 'Your Pie' 'Taste of India'
#  "Brett's Restaurant" 'Mochinut' "Willy's Mexicana Grill" "Jimmy John's"
#  "Dunkin'" 'Variety Mart' 'Planet Smoothie' 'Chicken Salad Chick'
#  'Preacher Green’s' 'The Crab Hut' 'The Place' 'Pizza Factory'
#  'D92 Korean BBQ' 'Golden Pantry' "The People's Pantry"
#  'West Broad Nutrition' 'OK! Coffee' 'I Love Mac & Cheese' 'Five Bar'
#  "Marti's at Midday" 'J. Buffalo Wings' '@local.' "Marco's Pizza"
#  'Bon de Paris' 'Cicis Pizza' 'Athens Seafood Market' 'Roll It Up'
#  'WNB Factory' 'The Clayton Social' "Sam's Food Mart" 'Cheers! Package'
#  'Golden Sun' 'Subway' 'El Bajio' "Domino's" 'Magic Smoke'
#  'Chuck E. Cheese' 'On the Way Food Stores' 'Utage'
#  'Angeles J. Supermarket & Taqueria' 'Sr. Sol' 'Inoko Express' 'Gyro Wrap'
#  "Papa John's" "Dooley's Bar & Grill"
#  "Corner's Edge Butcher Shoppe of Athens" 'Siri Thai Cuisine'
#  'Cool World Ice Cream Shop' 'Biscuit Basket' 'Bubble Cafe'
#  "Johnny's Pizza" 'Vampire Penguin Shaved Snow and Coffee' 'TA'
#  'Larry’s Giant Subs' 'Chef Ming' 'WnB Factory: Wings & Burger'
#  'home.made' 'Pizza Hut' 'Shane’s Rib Shack' 'Golden Panda'
#  'Panda Express' 'The Niche Pizza Company' 'Nowhere Bar'
#  'Athena Mediterranean Kitchen' "ZZ & Simone's" "Billy & Beau's Coffee"
#  'Another Broken Egg Cafe' 'J.C. Food Store' 'On the Way Package'
#  'Village Summit Dining Commons' 'Market at East Campus' 'Clean Eatz'
#  'Poké Bar' 'Killer Crust Pizza Company' "Wok's Up" 'Dos Palmas'
#  'Baxter Food Mart' 'The Bar @ Saucehouse' "Mama's Boy" 'Taco Mama'
#  'Blenderz Smoothies & Bowls' 'Lickin Chicken' 'Punta Cana Latin Grill'
#  'Poquitos' 'Emmy Squared Pizza' 'Chevron' "Traveling Chick'n"
#  'Rothenberger Café' "Dunkin' Donuts" "Newk's Eatery" "Bee's Knees Bakery"
#  "Harry's" "Harry's Liquor" 'Catch 22 Gastropub' 'Nothing Bundt Cakes'
#  'The Niche Dining Commons' 'Sweetie Pie by Savie' 'La Parrilla'
#  'The Lark' "McDonald's" 'Jersey Mike’s Subs'
#  'Tokyo Express Hibachi Grill' 'Daydreamer Cafe' 'Panera Bread']
# ------
# Unique values in shop (SLO):
#  ['bakery' 'convenience' 'alcohol' 'confectionery' 'wine'
#  'brewing_supplies' 'coffee' 'tea' 'greengrocer' 'pastry' 'butcher']
# ------
# Unique values in shop (Davis):
#  ['bakery' 'convenience' 'wine' 'tea' 'confectionery']
# ------
# Unique values in shop (Athens):
#  ['convenience' 'ice_cream' 'bakery' 'pastry' 'alcohol' 'wine'
#  'health_food' 'seafood' 'butcher']
# ------

# %% [markdown]
# ^^ Most of these values seem nice to work with and are easy to read. However, for `cuisine`, some values are repeated with different wordings. This includes:
# * values containing mutiple cuisines separated by `;` (ex's: 'burger;diner', 'hot_dog;pizza;sandwich', 'street_food;burger;mexican;american')
# * some of these combined values contain cuisines that are unrelated (ex: 'pizza;wine;beer' where 'wine' and 'beer' are not cuisines)
#
# Additionally, the `amenity`, `cuisine`, and `shop` variables includes values with underscores, which should be replaced with spaces for consistency with other variables.

# %%
for parquet in [slofood_parquet, davisfood_parquet, athensfood_parquet]:
    multi_cuisine_rows = parquet[parquet['cuisine'].str.contains(';', na=False)]
    print(multi_cuisine_rows[['name', 'cuisine']])
# Out:
#                               name                              cuisine
# 21                 Mustang Station                      pizza;wine;beer
# 110                  Cool Cat Cafe                         burger;diner
# 183              Costco Food Court               hot_dog;pizza;sandwich
# 189  Taqueria Santa Cruz Express 2                      mexican;burrito
# 241                     Raku Ramen                noodle;japanese;ramen
# 244                      Poke Chef                           sushi;poke
# 245                        Ziggy's           american;mexican;ice_cream
# 254                        Streats  street_food;burger;mexican;american
# 271                     Jay Bird's                     chicken;sandwich
# 277         Nautical Bean - Bunker                   coffee_shop;bistro
#                                              name  \
# 16                               Burgers and Brew
# 19                                      Make Fish
# 21                              Woodstock's Pizza
# 28                                  Redrum Burger
# 41                             The Dumpling House
# 48                                   Panera Bread
# 53                         Segundo Dining Commons
# 64                                   I Love Sushi
# 74   Natural Food Works and Farmer's Kitchen Cafe
# 97                                       Tea List
# 114                             Red 88 Noodle Bar
# 115                      Fuji Sushi Boat & Buffet
# 117                                The Posh Bagel
# 119                  Four Seasons Gourmet Chinese
# 120                       Dos Coyotes Border Cafe
# 121                     Mr Pickle's Sandwich Shop
# 122                                    Teabo Café
# 169                                Raising Cane's
# 171                                      El patio
#
#                                         cuisine
# 16                          burger;fries;drinks
# 19                       japanese;sushi;seafood
# 21                            pizza;salad;wings
# 28                              burger;american
# 41                             chinese;dumpling
# 48                              sandwich;bakery
# 53   american;burger;sandwich;chicken;breakfast
# 64                               japanese;sushi
# 74                                organic;local
# 97                                   tea;coffee
# 114                                noodle;asian
# 115                       sushi;japanese;buffet
# 117                         bagel;breakfast;tea
# 119                             chinese;italian
# 120                             tex-mex;mexican
# 121                               sandwich;soup
# 122                             bubble_tea;cafe
# 169                     american;burger;chicken
# 171                            american;mexican
#                          name                             cuisine
# 41                 Athens Wok  chinese;japanese;thai;asian;fusion
# 55                Mannaweenta                  ethiopian;eritrean
# 58           Blind Pig Tavern                     burger;american
# 61                  Choo Choo                     japanese;korean
# 115    Bulldawg Pizza & Wings                         pizza;wings
# 133      Ahi Hibachi and Poke                   japanese;hawaiian
# 154              Little Italy                       italian;pizza
# 190                  Mochinut                    donut;bubble_tea
# 193                   Dunkin'                   donut;coffee_shop
# 200              The Crab Hut                  seafood;vietnamese
# 216               Cicis Pizza                        pizza;buffet
# 219               WNB Factory                        wings;burger
# 247               Bubble Cafe                    bubble_tea;asian
# 300                     Amici                         pizza;wings
# 315         Traveling Chick'n                     wings;breakfast
# 321            Dunkin' Donuts                   donut;coffee_shop
# 322             Newk's Eatery                      pizza;sandwich
# 328  The Niche Dining Commons         sandwich;burger;pizza;salad
# 336              Panera Bread                     sandwich;bakery

# %% [markdown]
# Manually looking through all the combined cuisines, however, show that they do pertain to all those cuisines. For cleaning, split the cuisines up as a list and keep them like that so if I wanted to filter through and search a specific cuisine can be uneecessarily complex. So, another way to handle it is keeping it as a string and using commas as separation.

# %%
# cleaning `cuisine` and `amenity` variables

# replace '_' with ' ' 
for parquet in [slofood_parquet, davisfood_parquet, athensfood_parquet]: 
    parquet['cuisine'] = parquet['cuisine'].str.replace('_', ' ')
    parquet['amenity'] = parquet['amenity'].str.replace('_', ' ')
    parquet['shop'] = parquet['amenity'].str.replace('_', ' ')

# multi-value handling (split into list)
for parquet in [slofood_parquet, davisfood_parquet, athensfood_parquet]: 
    parquet['cuisine'] = parquet['cuisine'].str.replace(';', ', ')
    # parquet["cuisine"] = parquet["cuisine"].dropna().apply(lambda x: x.split(";") if ";" in x else [x]) # even if it's only one cuisine, make it a list for consistency

# %%
for col in ['amenity', 'cuisine', 'shop']:
    if col in slofood_parquet.columns:
        print(f"Unique values in {col} (SLO):\n", slofood_parquet[col].dropna().astype(str).unique())
        print("------")

    if col in davisfood_parquet.columns:
        print(f"Unique values in {col} (Davis):\n", davisfood_parquet[col].dropna().astype(str).unique())
        print("------")

    if col in athensfood_parquet.columns:
        print(f"Unique values in {col} (Athens):\n", athensfood_parquet[col].dropna().astype(str).unique())
        print("------")
# Out:
# Unique values in amenity (SLO):
#  ['fast food' 'cafe' 'restaurant' 'bar' 'vending machine' 'pub' 'bbq'
#  'ice cream' 'biergarten']
# ------
# Unique values in amenity (Davis):
#  ['fast food' 'vending machine' 'cafe' 'pub' 'restaurant' 'ice cream' 'bbq'
#  'bar']
# ------
# Unique values in amenity (Athens):
#  ['restaurant' 'pub' 'bar' 'pharmacy' 'cafe' 'fast food' 'ice cream' 'bbq'
#  'vending machine']
# ------
# Unique values in cuisine (SLO):
#  ['sandwich' 'coffee shop' 'tex-mex' 'sushi' 'cajun' 'thai' 'bagel'
#  'mediterranean' 'pizza, wine, beer' 'pizza' 'irish' 'mexican' 'ramen'
#  'chinese' 'burger' 'breakfast' 'japanese' 'italian' 'barbecue' 'asian'
#  'juice' 'indian' 'crepe' 'american' 'french' 'international' 'german'
#  'burger, diner' 'chicken' 'turkish' 'frozen yogurt' 'poke' 'bakery'
#  'steak house' 'hot dog, pizza, sandwich' 'mexican, burrito' 'bubble tea'
#  'noodle, japanese, ramen' 'sushi, poke' 'american, mexican, ice cream'
#  'noodle' 'street food, burger, mexican, american' 'chicken, sandwich'
#  'peruvian' 'coffee shop, bistro' 'cookies' 'fish']
# ------
# Unique values in cuisine (Davis):
#  ['mexican' 'chicken' 'coffee shop' 'pizza' 'burger' 'tex-mex' 'ice cream'
#  'breakfast' 'burger, fries, drinks' 'japanese, sushi, seafood' 'regional'
#  'pizza, salad, wings' 'thai' 'burger, american' 'bagel' 'juice' 'hot dog'
#  'chinese, dumpling' 'sushi' 'sandwich, bakery'
#  'american, burger, sandwich, chicken, breakfast' 'cake' 'asian'
#  'bubble tea' 'japanese, sushi' 'chinese' 'organic, local' 'sandwich'
#  'indian' 'japanese' 'tea, coffee' 'american' 'italian' 'wings'
#  'noodle, asian' 'sushi, japanese, buffet' 'bagel, breakfast, tea'
#  'chinese, italian' 'tex-mex, mexican' 'sandwich, soup' 'bubble tea, cafe'
#  'french' 'mediterranean' 'vietnamese' 'american, burger, chicken'
#  'american, mexican' 'greek']
# ------
# Unique values in cuisine (Athens):
#  ['coffee shop' 'burger' 'regional' 'american' 'japanese' 'mediterranean'
#  'juice' 'seafood' 'mexican' 'chinese, japanese, thai, asian, fusion'
#  'bagel' 'pizza' 'ice cream' 'ethiopian, eritrean' 'burger, american'
#  'japanese, korean' 'chicken' 'bubble tea' 'dessert' 'pita' 'thai' 'wings'
#  'chinese' 'pizza, wings' 'japanese, hawaiian' 'italian, pizza' 'italian'
#  'deli' 'vietnamese' 'asian' 'breakfast' 'indian' 'donut, bubble tea'
#  'sandwich' 'donut, coffee shop' 'smoothie' 'seafood, vietnamese' 'korean'
#  'pizza, buffet' 'wings, burger' 'sushi' 'greek' 'bubble tea, asian'
#  'southern' 'wings, breakfast' 'pizza, sandwich'
#  'sandwich, burger, pizza, salad' 'sandwich, bakery']
# ------
# Unique values in shop (SLO):
#  ['fast food' 'cafe' 'restaurant' 'bar' 'vending machine' 'pub' 'bbq'
#  'ice cream' 'biergarten']
# ------
# Unique values in shop (Davis):
#  ['fast food' 'vending machine' 'cafe' 'pub' 'restaurant' 'ice cream' 'bbq'
#  'bar']
# ------
# Unique values in shop (Athens):
#  ['restaurant' 'pub' 'bar' 'pharmacy' 'cafe' 'fast food' 'ice cream' 'bbq'
#  'vending machine']
# ------

# %% [markdown]
# This is what the final values in each parquet look like:

# %%
for col in ['amenity', 'brand', 'cuisine', 'name', 'shop']:
    if col in slofood_parquet.columns:
        print(f"Unique values in {col} (SLO):\n", slofood_parquet[col].dropna().astype(str).unique())
        print("------")

    if col in davisfood_parquet.columns:
        print(f"Unique values in {col} (Davis):\n", davisfood_parquet[col].dropna().astype(str).unique())
        print("------")

    if col in athensfood_parquet.columns:
        print(f"Unique values in {col} (Athens):\n", athensfood_parquet[col].dropna().astype(str).unique())
        print("------")
# Out:
# Unique values in amenity (SLO):
#  ['fast food' 'cafe' 'restaurant' 'bar' 'vending machine' 'pub' 'bbq'
#  'ice cream' 'biergarten']
# ------
# Unique values in amenity (Davis):
#  ['fast food' 'vending machine' 'cafe' 'pub' 'restaurant' 'ice cream' 'bbq'
#  'bar']
# ------
# Unique values in amenity (Athens):
#  ['restaurant' 'pub' 'bar' 'pharmacy' 'cafe' 'fast food' 'ice cream' 'bbq'
#  'vending machine']
# ------
# Unique values in brand (SLO):
#  ["Jersey Mike's Subs" 'Starbucks' 'Taco Bell' '7-Eleven' "Domino's"
#  'Subway' 'Panda Express' 'Five Guys' 'Redbox' 'El Pollo Loco'
#  'The Habit Burger Grill' 'Rocky Mountain Chocolate Factory' 'Papyrus'
#  'Jamba' "See's Candies" 'Popeyes' 'Which Wich?' 'Round Table Pizza'
#  'Blaze Pizza' 'Yogurtland' 'Costco' 'Insomnia Cookies'
#  'Einstein Bros. Bagels']
# ------
# Unique values in brand (Davis):
#  ['Del Taco' 'KFC' "Peet's Coffee" 'Jack in the Box' 'Taco Bell' 'Chipotle'
#  'Starbucks' "Noah's Bagels" 'Jamba' 'The Habit Burger Grill'
#  'Panera Bread' 'Burger King' "Domino's" "Papa Murphy's" 'Quickly'
#  'Dutch Bros. Coffee' 'Subway' 'Round Table Pizza' 'Baskin-Robbins'
#  'Sharetea' 'Gong Cha' 'Wingstop' 'Blaze Pizza' 'Philz Coffee'
#  'Little Caesars' "Mountain Mike's" 'Panda Express' "Denny's"
#  "Ike's Love and Sandwiches" "Raising Cane's"]
# ------
# Unique values in brand (Athens):
#  ['Smoothie King' 'Mellow Mushroom' 'Five Guys' 'Starbucks' "Ben & Jerry's"
#  'Crumbl Cookies' 'Einstein Bros. Bagels' 'American Deli' 'Chick-fil-A'
#  "Taziki's Mediterranean Cafe" 'Pita Pit' 'Insomnia Cookies'
#  'Waffle House' 'Shell' 'Little Caesars' 'Chipotle' "Beef O'Brady's"
#  'Mochinut' "Jimmy John's" "Dunkin'" 'Planet Smoothie'
#  'Chicken Salad Chick' 'Pizza Factory' "Marco's Pizza" 'Cicis' 'Chevron'
#  'Subway' "Domino's" 'Chuck E. Cheese' "Papa John's" 'TA' 'Pizza Hut'
#  'Panda Express' 'Clean Eatz' 'Nothing Bundt Cakes' "McDonald's"
#  'Panera Bread']
# ------
# Unique values in cuisine (SLO):
#  ['sandwich' 'coffee shop' 'tex-mex' 'sushi' 'cajun' 'thai' 'bagel'
#  'mediterranean' 'pizza, wine, beer' 'pizza' 'irish' 'mexican' 'ramen'
#  'chinese' 'burger' 'breakfast' 'japanese' 'italian' 'barbecue' 'asian'
#  'juice' 'indian' 'crepe' 'american' 'french' 'international' 'german'
#  'burger, diner' 'chicken' 'turkish' 'frozen yogurt' 'poke' 'bakery'
#  'steak house' 'hot dog, pizza, sandwich' 'mexican, burrito' 'bubble tea'
#  'noodle, japanese, ramen' 'sushi, poke' 'american, mexican, ice cream'
#  'noodle' 'street food, burger, mexican, american' 'chicken, sandwich'
#  'peruvian' 'coffee shop, bistro' 'cookies' 'fish']
# ------
# Unique values in cuisine (Davis):
#  ['mexican' 'chicken' 'coffee shop' 'pizza' 'burger' 'tex-mex' 'ice cream'
#  'breakfast' 'burger, fries, drinks' 'japanese, sushi, seafood' 'regional'
#  'pizza, salad, wings' 'thai' 'burger, american' 'bagel' 'juice' 'hot dog'
#  'chinese, dumpling' 'sushi' 'sandwich, bakery'
#  'american, burger, sandwich, chicken, breakfast' 'cake' 'asian'
#  'bubble tea' 'japanese, sushi' 'chinese' 'organic, local' 'sandwich'
#  'indian' 'japanese' 'tea, coffee' 'american' 'italian' 'wings'
#  'noodle, asian' 'sushi, japanese, buffet' 'bagel, breakfast, tea'
#  'chinese, italian' 'tex-mex, mexican' 'sandwich, soup' 'bubble tea, cafe'
#  'french' 'mediterranean' 'vietnamese' 'american, burger, chicken'
#  'american, mexican' 'greek']
# ------
# Unique values in cuisine (Athens):
#  ['coffee shop' 'burger' 'regional' 'american' 'japanese' 'mediterranean'
#  'juice' 'seafood' 'mexican' 'chinese, japanese, thai, asian, fusion'
#  'bagel' 'pizza' 'ice cream' 'ethiopian, eritrean' 'burger, american'
#  'japanese, korean' 'chicken' 'bubble tea' 'dessert' 'pita' 'thai' 'wings'
#  'chinese' 'pizza, wings' 'japanese, hawaiian' 'italian, pizza' 'italian'
#  'deli' 'vietnamese' 'asian' 'breakfast' 'indian' 'donut, bubble tea'
#  'sandwich' 'donut, coffee shop' 'smoothie' 'seafood, vietnamese' 'korean'
#  'pizza, buffet' 'wings, burger' 'sushi' 'greek' 'bubble tea, asian'
#  'southern' 'wings, breakfast' 'pizza, sandwich'
#  'sandwich, burger, pizza, salad' 'sandwich, bakery']
# ------
# Unique values in name (SLO):
#  ["Jersey Mike's Subs" 'Starbucks' 'Taco Bell' "Farb's Bakery"
#  'Slo Asian Market' 'SLO Provisions' 'Black Sheep Bar & Grill'
#  "Woodstock's Pizza" 'Yanagi Sushi' 'Bon Temps Creole Cafe' 'My Thai'
#  "Gus's Grocery" 'Village Market' '7-Eleven' 'House of Bagels'
#  'Jaffa Cafe' 'Health Snacks' 'Mustang Station'
#  'Blackhorse Espresso and Bakery' "Domino's" "Charlie's Place"
#  "SLO Beverage 'n More" 'Subway' 'Laurel Lane Liquors' "Pappy McGregor's"
#  'Chronic Tacos' "Nucci's" "Sally Loo's Wholesome Cafe"
#  'Crossroads Liquor & Deli' "Sandy's Deli & Liquor" 'Raku Ramen'
#  "Capriottti's Sandwich Shop" 'Panda Express' 'SLO Donut Company'
#  'Five Guys' "Nucci's Pizza" 'Redbox' 'El Pollo Loco'
#  "Pancho's Mexican Food" 'Eureka! Burger' "Louisa's Place"
#  "Linnaea's Cafe" "Eddie's Grill" 'Thai Boat' "Kona's Deli"
#  'Kumi-Ko Japanese' 'The Habit Burger Grill' 'Nautical Bean' 'La Locanda'
#  'Rocket Fizz' 'Central Coast Wines' 'New Earth Superfoods' "Jan's Place"
#  'CJ’s BBQ' 'Thai Palace' 'Aisuru Sushi' "Bowl'd" "Bull's Tavern"
#  "Pluto's" 'Bings Bao Buns' 'UBATUBA, Acai bowls' 'Shadow Canyon Cellars'
#  'Rocky Mountain Chocolate Factory' "Giuseppe's Cucina Rustica"
#  "Doc Bernstein's Ice Cream Lab" "McConnell's Fine Ice Creams"
#  'Brown Butter Cookie Company' 'Urbane Cafe'
#  "Pancho Villa's Mexican Restaurant" 'Creeky Tiki' 'Jamba' 'Taj Palace'
#  "See's Candies" 'Le Ciel Crepe Cafe' 'Flour House' 'Old San Luis BBQ Co'
#  'Burger Village' 'Outspoken Cafe' 'Tacos De Acapulco' 'The Bobastop'
#  'Sushi Kokku' 'Taqueria Santa Cruz Express'
#  'Mama Ganache Artisan Chocolates' 'Goshi Japanese Restaurant'
#  'Laguna Bar and Grill' 'Ribline' 'Et Voilà' 'Stephen Ross Wine Cellars'
#  'Budget Cafe' 'Red Radish' 'Tacos de Aculpuco' 'Sweetie Cup Tea House'
#  "Beda's Biergarten" 'Cool Cat Cafe' 'Freshh Donuts' 'Taco Roco'
#  "Tahoe Joe's" 'Popeyes' 'Apple Farm' 'Koberl at Blue' 'Which Wich?'
#  'Nautical Bean Espresso Cafe' 'Luis Wine Bar' 'Coastal Peaks Roasters'
#  "Doc's Cellar" 'Sidecar' 'Scout Coffee Co.' 'Oki Momo'
#  'Round Table Pizza' "Fatte's Pizza" 'The Neighborhood' 'Blaze Pizza'
#  'San Luis Fish BBQ' 'Central Coast Brewing' 'Hoagies'
#  "McCarthy's Irish Pub" 'Kreuzberg'
#  'The Libertine Brewing Company and Coffee Bar' "Mother's Tavern"
#  'Buffalo Pub and Grill' 'LOKUM' 'Batch' 'Scout Coffee Company'
#  'Tacos Y Birria Sinalos' 'Novo Restaurant & Lounge'
#  'Metro Brewing Company' 'Buona Tavola' 'Mint and Craft'
#  'Mee Heng Low Noodle House' 'SLO Sweets' 'Yogurtland' 'Firestone Grill'
#  'Blackhorse Espresso & Bakery - Uptown' 'Granada Hotel & Bistro'
#  'Mongo Madness' 'The Library' 'Seeds' 'SLO Cafe & Market Place'
#  'Cerro Caliente Cellars' 'SLO Maid Ice Cream' 'Aloha Cafe' 'Front Porch'
#  'PokiRito' "Tonita's" 'Secret Garden' 'Le Petit Paris'
#  'Bang the Drum Brewery' 'House of Bread' 'Ox & Anchor' 'Piadina'
#  'S.Low Bar' 'Cornercopia Fresh Market' 'Costco Food Court'
#  'La Esquina Taqueria' 'Taqueria Santa Cruz Express 2' 'Milk Tea Society'
#  'Milk In It' 'Insomnia Cookies' 'Poke Chef' "Ziggy's"
#  'Market Grand Avenue' 'Balance Cafe' 'Hearth' 'Brunch' 'Noodles'
#  'Sweet Bar' 'Streats' 'Mingle + Nosh' 'Shake Smart' "Julian's"
#  'Einstein Bros. Bagels' 'La Esquina Distillery' 'The Mark Bar & Grill'
#  'Snofari Frozen Yogurt' "Mr. Pickle's Sandwich Shop"
#  'Efren’s Mexican Restaurant' 'Alex Madonna Gold Rush Steakhouse'
#  'Copper Cafe' 'Silver Bar Cocktail Lounge' "Jay Bird's" 'Bread Bike'
#  'Corazon Cafe SLO' '15 Degrees C' "My Friend Mike's" 'Coya Peruvian'
#  'Nautical Bean - Bunker' 'Cowboy Cookie and Ice Cream' 'Ancient Owl'
#  'Kaffein Coffee Company' 'Cal Poly Meats' 'Pizza Republic'
#  'Negranti Creamery' 'Arigato Sushi' 'Deltina Coffee' 'Tiki Hut'
#  'Lure Fish House']
# ------
# Unique values in name (Davis):
#  ['Del Taco' 'KFC' 'Cargo Coffee' 'Sodexho Coffee' 'Bio Brew'
#  "Peet's Coffee" 'Gunrock Pub' "Steve's Pizza" 'Jack in the Box'
#  'Taco Bell' 'Chipotle' 'Cultivé Frozen Yogurt' 'Crepeville'
#  'Burgers and Brew' 'Yolo Berry' 'Silver Dragon' 'Make Fish' 'Bistro 33'
#  "Woodstock's Pizza" 'Kathmandu Kitchen' 'Village Bakery'
#  'Davis Noodle City' 'Davis Creamery' "Sophia's Thai Kitchen"
#  'Village Pizza & Grill' 'Redrum Burger' 'Starbucks'
#  'Taqueria Guadalajara' 'Dos Coyotes' "Noah's Bagels" 'Jamba'
#  'Lamppost Pizza' 'Shanghai Town' "Chuy's Taqueria"
#  'Symposium Restaurant & Pizza House' 'Taste of Thai' 'The Hotdogger'
#  'The Dumpling House' 'Snack Shack' 'Sudwerk Brewing Co. The Dock'
#  'The Habit Burger Grill' "Mikuni's" 'Panera Bread' "Shah's Halal Food"
#  'CoHo South Café' 'Cuarto Dining Commons' 'Segundo Dining Commons'
#  'Tercero Dining Commons' 'Burger King' "Domino's" 'KetMoRee' 'Konditorei'
#  'Let Them Eat Cake' 'Ding How' "Papa Murphy's" 'Quickly' 'I Love Sushi'
#  'Sage Street Cafe' 'Sage Street Restaurant' 'Sage Street Market'
#  'Wok of Flame' 'Fluffy Donuts' 'The Old Teahouse' 'The Graduate'
#  'Coffee House' "Natural Food Works and Farmer's Kitchen Cafe"
#  'Dutch Bros. Coffee' 'El Toro Bravo' 'Subway' 'Round Table Pizza'
#  '3rd and U Cafe' 'Ali Baba Cafe' 'Pho King 4 Restaurant' 'Oshio Cafe'
#  "Raja's Tandoor" 'Baskin-Robbins' 'Manna Korean BBQ'
#  'Taqueria El Burrito' 'Yeti Restaurant' "Zia's Delicatessen"
#  'Taqueria Davis' 'Thai Canteen' "Pluto's" 'Yakitori Yuchan'
#  'The Davis Beer Shoppe' 'Common Grounds Coffee' 'Tea List' 'Sharetea'
#  'Barista Brew Cafe' 'Cafe Bernardo' 'Cloud Forest Cafe' "Bull 'N Mouth"
#  'Burger Patch' 'Temple Coffee' 'Bar Bernardo' "Jack's Urban Eats"
#  'University of Beer' 'vini' 'Gong Cha' "Paesano's" 'Wingstop'
#  'Red 88 Noodle Bar' 'Fuji Sushi Boat & Buffet' 'Preethi Indian Cuisine'
#  'The Posh Bagel' 'Blaze Pizza' 'Four Seasons Gourmet Chinese'
#  'Dos Coyotes Border Cafe' "Mr Pickle's Sandwich Shop" 'Teabo Café'
#  'La Cocina Mexicana Restaurante' "Davis's Piñata Mexican Grill"
#  'Fushion Fresh Cafe' 'Philz Coffee' 'Dunloe Brewing' 'Huku Bistro'
#  'Little Caesars' 'Carniceria Lupita' 'Asian Garden' 'Burma Eat'
#  "Mountain Mike's" 'Panda Express' 'Crepe Bistro' 'Spokes Grill'
#  'Silo Market' "Denny's" 'Lazi Cow' 'Latitude Restaurant' 'Wundebar'
#  'Xi Square' 'Hunan Style' "Ike's Love and Sandwiches" 'Pachamama Coffee'
#  "Froggy's" "Raising Cane's" 'Sit Lo Saigon' "Kiki's Chicken Place"
#  'Insomnia cookies' 'Myu Myu' 'El patio' 'Nick the Greek']
# ------
# Unique values in name (Athens):
#  ['The National' "Jittery Joe's Coffee" 'Baddies' 'Birdies'
#  'Big City Bread Cafe' 'Pulaski Heights BBQ' 'Trappeze Pub'
#  'Manhattan Cafe' 'Little Kings Shuffle Club' 'The Roadhouse' 'The Globe'
#  'Bar South' 'Woodford' 'Cutters Pub' "Pauley's Crepe Bar" 'Rye Bar'
#  "General Beauregard's" 'City Bar' "Walker's Coffee and Pub"
#  'Blue Sky Bar' "Magnolia's" 'Bourbon Street' 'Buddha Bar'
#  '1785 Bar & Grill' "Flanagan's & The Half Moon Pub" 'Allgood Lounge'
#  'On The Rocks' "Boar's Head Lounge" 'South Kitchen + Bar'
#  'The Pine Bar & The Root Basement' 'Sakura Hibachi & Sushi Bar'
#  "Hodgson's Pharmacy & Gift Shop" 'Mediterranean Grill'
#  'Independent Baking Company' 'Smoothie King' 'Dawg Gone Good BBQ'
#  'Square One Fish Co.' "Em's Kitchen" 'La Cabana de Don Juan' 'Athens Wok'
#  'Athens Bagel Company' 'Mellow Mushroom' 'The Grill' 'Five Guys'
#  'Ten Pins Tavern' 'The World Famous' 'Starbucks' 'Sabor Latino'
#  "Ben & Jerry's" 'Hi-Lo Lounge' 'The Old Pal' 'Crumbl Cookies'
#  'JR Crickets' 'Mannaweenta' 'Lighthouse Seafood' 'Vanish Night Club'
#  'Blind Pig Tavern' 'Einstein Bros. Bagels' 'Taqueria La Parrilla'
#  'Choo Choo' 'American Deli' "Mama Sid's Pizza" 'Ideal Bagel Co.'
#  'Chick-fil-A' "Jittery Joe's" 'Cravings' 'LRG Provisions' 'Clocked'
#  "Taziki's Mediterranean Cafe" 'Ding Tea' 'The Office' '1000 Faces Coffee'
#  'Buvez!' 'Pelican’s Snoballs' 'Pita Pit' 'Taqueria Tsunami' 'Cozy Bar'
#  'Wonderbar' 'Spirits on Washington' 'SandBar' 'The Silver Dollar Bar'
#  'Insomnia Cookies' 'Bad Moon' 'Moonshine Bar' 'Eddie’s Calzones & Drafts'
#  'Amici' 'Barberitos' "Sister Louisa's Church" 'Tropical Bar' 'Shokitini'
#  'Creature Comforts' 'Frogger' 'Hendershot’s' 'Pretty Boy'
#  'Seabear Oyster Bar' 'Ponko Chicken' 'Wingster' 'Waffle House'
#  'Golden Pantry Market' 'Fast Trac' 'Journey Juice' "Sam's" 'Agua Linda'
#  'Normal Bar' 'Oglethorpe Bar' 'Tall Boy Beverage Company' 'Fooks Foods'
#  'China 1' 'Bulldawg Pizza & Wings' 'Shell' 'Golden Dragon'
#  'Little Caesars' 'Ahi Hibachi and Poke' "Iguana's Mexican Grill"
#  'J. Christopher’s' 'Heirloom Cafe' 'Vickars Nutritionist' 'Chipotle'
#  'Lindsey’s Culinary Market' 'Farm Burger' 'Lumberjaxe' 'Tapped Athens'
#  'Last Resort Grill' 'Flicker Theatre & Bar'
#  'Empourium Rooftop and Lounge' 'Canyons-Convenience Store'
#  "Clarke's Collective" 'Bear Hug Honey' 'The Rook & Pawn'
#  'Alumni Cookie Dough' 'DP Dough' 'Thai Spoon' 'Little Italy'
#  "DePalma's Italian Cafe" 'The Double Barrel' 'Porterhouse Grill'
#  'Up Dawg' 'JINYA Ramen Bar' 'Osteria Athena' 'Bruxie' 'Munch Hut'
#  'Mother Phở' 'Taichi Bubble Tea' 'Four Fat Cows' 'Choco Pronto'
#  'Slutty Vegan' 'Newk’s Eatery' 'Camino Real Taqueria'
#  'Village Wine & Spirits' 'Inoko Hibachi Express Eastside'
#  "Beef O'Brady's" 'The Taco Stand' 'Locos Grill & Pub'
#  'Depalmas Italian Cafe' 'New Red Bowl Asian Bistro' 'Groove Burgers'
#  'The Flying Biscuit Cafe' 'Just Phở ...and More' 'Booze R Uals'
#  'Surcheros' 'The Juicy Crab' 'Your Pie' 'Taste of India'
#  "Brett's Restaurant" 'Mochinut' "Willy's Mexicana Grill" "Jimmy John's"
#  "Dunkin'" 'Variety Mart' 'Planet Smoothie' 'Chicken Salad Chick'
#  'Preacher Green’s' 'The Crab Hut' 'The Place' 'Pizza Factory'
#  'D92 Korean BBQ' 'Golden Pantry' "The People's Pantry"
#  'West Broad Nutrition' 'OK! Coffee' 'I Love Mac & Cheese' 'Five Bar'
#  "Marti's at Midday" 'J. Buffalo Wings' '@local.' "Marco's Pizza"
#  'Bon de Paris' 'Cicis Pizza' 'Athens Seafood Market' 'Roll It Up'
#  'WNB Factory' 'The Clayton Social' "Sam's Food Mart" 'Cheers! Package'
#  'Golden Sun' 'Subway' 'El Bajio' "Domino's" 'Magic Smoke'
#  'Chuck E. Cheese' 'On the Way Food Stores' 'Utage'
#  'Angeles J. Supermarket & Taqueria' 'Sr. Sol' 'Inoko Express' 'Gyro Wrap'
#  "Papa John's" "Dooley's Bar & Grill"
#  "Corner's Edge Butcher Shoppe of Athens" 'Siri Thai Cuisine'
#  'Cool World Ice Cream Shop' 'Biscuit Basket' 'Bubble Cafe'
#  "Johnny's Pizza" 'Vampire Penguin Shaved Snow and Coffee' 'TA'
#  'Larry’s Giant Subs' 'Chef Ming' 'WnB Factory: Wings & Burger'
#  'home.made' 'Pizza Hut' 'Shane’s Rib Shack' 'Golden Panda'
#  'Panda Express' 'The Niche Pizza Company' 'Nowhere Bar'
#  'Athena Mediterranean Kitchen' "ZZ & Simone's" "Billy & Beau's Coffee"
#  'Another Broken Egg Cafe' 'J.C. Food Store' 'On the Way Package'
#  'Village Summit Dining Commons' 'Market at East Campus' 'Clean Eatz'
#  'Poké Bar' 'Killer Crust Pizza Company' "Wok's Up" 'Dos Palmas'
#  'Baxter Food Mart' 'The Bar @ Saucehouse' "Mama's Boy" 'Taco Mama'
#  'Blenderz Smoothies & Bowls' 'Lickin Chicken' 'Punta Cana Latin Grill'
#  'Poquitos' 'Emmy Squared Pizza' 'Chevron' "Traveling Chick'n"
#  'Rothenberger Café' "Dunkin' Donuts" "Newk's Eatery" "Bee's Knees Bakery"
#  "Harry's" "Harry's Liquor" 'Catch 22 Gastropub' 'Nothing Bundt Cakes'
#  'The Niche Dining Commons' 'Sweetie Pie by Savie' 'La Parrilla'
#  'The Lark' "McDonald's" 'Jersey Mike’s Subs'
#  'Tokyo Express Hibachi Grill' 'Daydreamer Cafe' 'Panera Bread']
# ------
# Unique values in shop (SLO):
#  ['fast food' 'cafe' 'restaurant' 'bar' 'vending machine' 'pub' 'bbq'
#  'ice cream' 'biergarten']
# ------
# Unique values in shop (Davis):
#  ['fast food' 'vending machine' 'cafe' 'pub' 'restaurant' 'ice cream' 'bbq'
#  'bar']
# ------
# Unique values in shop (Athens):
#  ['restaurant' 'pub' 'bar' 'pharmacy' 'cafe' 'fast food' 'ice cream' 'bbq'
#  'vending machine']
# ------

# %%
# save this as new parquet

slofood_parquet.to_parquet("slofood_cleaned.parquet", index=False)
davisfood_parquet.to_parquet("davisfood_cleaned.parquet", index=False)
athensfood_parquet.to_parquet("athensfood_cleaned.parquet", index=False)
